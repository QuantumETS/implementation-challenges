# %% [markdown]
# ### Installation des dépendances
#
# Exécutez la commande suivante pour installer les dépendances à partir de la racine du repo:
#
# ```bash
# uv sync --package vqa-qchem
# ```
#
# Un environnement virtuel devrait être créé, il pourra être utilisé avec ce notebook.

# %%
import pennylane as qml
from pennylane.ops.op_math import LinearCombination
import pprint as pp

# %%
hydroxide_dataset = qml.data.load("qchem", molname="OH-", bondlength=0.964, basis="STO-3G")
# h20_dataset = qml.data.load("qchem", molname="H2O", bondlength=0.958, basis="STO-3G", attributes=["hamiltonian", "hf_state", "tapered_hamiltonian"])
# ch2_dataset = qml.data.load("qchem", molname="CH2", bondlength=1.085, basis="STO-3G", attributes=["hamiltonian", "hf_state", "tapered_hamiltonian"])
# ch4_dataset = qml.data.load("qchem", molname="CH4", bondlength=1.086, basis="STO-3G", attributes=["hamiltonian", "hf_state", "tapered_hamiltonian"])
# co_dataset = qml.data.load("qchem", molname="CO", bondlength=1.128, basis="STO-3G", attributes=["hamiltonian", "hf_state", "tapered_hamiltonian"])
# co2_dataset = qml.data.load("qchem", molname="CO2", bondlength=1.162, basis="STO-3G", attributes=["hamiltonian", "hf_state", "tapered_hamiltonian"])

# %%
pp.pp(hydroxide_dataset[0].vqe_energy)
pp.pp(hydroxide_dataset[0].vqe_gates)
pp.pp(hydroxide_dataset[0].vqe_params)
pp.pp(hydroxide_dataset[0].tapered_hamiltonian)
# Out:
# np.float64(-74.07932161682672)
# ...

# %%
print(hydroxide_hamiltonian.num_wires)
# h20_hamiltonian = h20_dataset[0].tapered_hamiltonian
# print(h20_hamiltonian.num_wires)
# ch2_hamiltonian = ch2_dataset[0].tapered_hamiltonian
# print(ch2_hamiltonian.num_wires)
# ch4_hamiltonian = ch4_dataset[0].tapered_hamiltonian
# print(ch4_hamiltonian.num_wires)
# co_hamiltonian = co_dataset[0].tapered_hamiltonian
# print(co_hamiltonian.num_wires)
# co2_hamiltonian = co2_dataset[0].tapered_hamiltonian
# print(co2_hamiltonian.num_wires)
